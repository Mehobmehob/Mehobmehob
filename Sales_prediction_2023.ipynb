# %% [markdown]
# <a href="https://colab.research.google.com/github/Mehobmehob/Mehobmehob/blob/main/Sales_prediction_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# to mount drive the file
fpath="/content/drive/MyDrive/AXSOSACADEMY/01-Fundamentals/Week02/Data/sales_predictions_2023.csv"

# %%
# import pandas
import pandas as pd

# %%
# preview the data info
df=pd.read_csv(fpath)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
# preview data head
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# # Data Cleaning

# %%
# 1) How many rows and columns?
# Column 12
 # rows 8523
 # 2) What are the datatypes of each variable?
 # we have floats, integer and string/object

# %%
# 3) Are there duplicates? If so, drop any duplicates
duplicated_rows = df.duplicated().sum()
duplicated_rows
print(f"Number of duplicates: {duplicated_rows}")
# Out:
# Number of duplicates: 0

# %%
# vissually check duplicated rows
df[df.duplicated]
# Out:
# Empty DataFrame
# Columns: [Item_Identifier, Item_Weight, Item_Fat_Content, Item_Visibility, Item_Type, Item_MRP, Outlet_Identifier, Outlet_Establishment_Year, Outlet_Size, Outlet_Location_Type, Outlet_Type, Item_Outlet_Sales]
# Index: []

# %%
# 4) Identify missing values
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# 5) Address the missing values by using a placeholder value
#6) Confirm that there are no missing values after addressing them
df.fillna("missing", inplace=True)
df.isna().sum()
# Out:
# <ipython-input-85-d1c585022a52>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'missing' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna("missing", inplace=True)
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
#7) Find and fix any inconsistent categories of data (for example: fix cat, Cat, and cats so that they are consistent)

string_columns = df.select_dtypes(include=['object']).columns
for column in string_columns:
 print(f"Value Counts for {column}:")
 print(df[column].value_counts())
 print("\n")
# Out:
# Value Counts for Item_Identifier:
# Item_Identifier
# FDW13    10
# FDG33    10
# FDX31     9
# FDT07     9
# NCY18     9
#          ..
# FDO33     1
# FDK57     1
# FDT35     1
# FDN52     1
# FDE52     1
# Name: count, Length: 1559, dtype: int64
#
#
# Value Counts for Item_Weight:
# Item_Weight
# missing    1463
# 12.15        86
# 17.6         82
# 13.65        77
# 11.8         76
#            ...
# 5.21          2
# 9.42          1
# 7.685         1
# 5.4           1
# 6.52          1
# Name: count, Length: 416, dtype: int64
#
#
# Value Counts for Item_Fat_Content:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64
#
#
# Value Counts for Item_Type:
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# ...

# %%
# to replace the data
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace({'LF': 'Low Fat', 'low fat': 'Low Fat', 'reg': 'Regular'})

# %%
Item_Fat_Content_counts = df['Item_Fat_Content'].value_counts()
print(Item_Fat_Content_counts)
# Out:
# Item_Fat_Content
# Low Fat    5517
# Regular    3006
# Name: count, dtype: int64

# %%
#8) For any numerical columns, obtain the summary statistics of each (min, max, mean).
df['Item_Weight']= pd.to_numeric(df['Item_Weight'], errors='coerce')
# Now calculate the statistics
Statistic = df['Item_Weight'].mean()
print(Statistic)
# Out:
# 12.857645184135976

# %%
#Min
Statistic = df['Item_Weight'].min()
Statistic
# Out:
# 4.555

# %%
#max
Statistic = df['Item_Weight'].max()
Statistic
# Out:
# 21.35
